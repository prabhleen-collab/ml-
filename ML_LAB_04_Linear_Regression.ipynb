# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhleen-collab/ml-/blob/main/ML_LAB_04_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

X = np.random.rand(50, 1) * 100

# %%
X
# Out:
# array([[37.45401188],
#        [95.07143064],
#        [73.19939418],
#        [59.86584842],
#        [15.60186404],
#        [15.59945203],
#        [ 5.80836122],
#        [86.61761458],
#        [60.11150117],
#        [70.80725778],
#        [ 2.05844943],
#        [96.99098522],
#        [83.24426408],
#        [21.23391107],
#        [18.18249672],
#        [18.34045099],
#        [30.4242243 ],
#        [52.47564316],
#        [43.19450186],
#        [29.12291402],
#        [61.18528947],
#        [13.94938607],
#        [29.21446485],
#        [36.63618433],
#        [45.60699842],
#        [78.51759614],
#        [19.96737822],
#        [51.42344384],
#        [59.24145689],
#        [ 4.64504127],
#        [60.75448519],
#        [17.05241237],
#        [ 6.5051593 ],
#        [94.88855373],
#        [96.56320331],
#        [80.83973481],
#        [30.46137692],
#        [ 9.7672114 ],
#        [68.42330265],
#        [44.01524937],
#        [12.20382348],
#        [49.51769101],
#        [ 3.43885211],
#        [90.93204021],
#        [25.87799816],
#        [66.25222844],
#        [31.17110761],
#        [52.00680212],
#        [54.67102793],
#        [18.48544555]])

# %%
np.random.seed(42)

X = np.random.rand(1000, 20) * 100

# %%
X
# Out:
# array([[37.45401188, 95.07143064, 73.19939418, ..., 52.47564316,
#         43.19450186, 29.12291402],
#        [61.18528947, 13.94938607, 29.21446485, ...,  9.7672114 ,
#         68.42330265, 44.01524937],
#        [12.20382348, 49.51769101,  3.43885211, ..., 19.59828624,
#          4.52272889, 32.53303308],
#        ...,
#        [ 9.19645673, 57.53817036, 97.80981193, ..., 87.72033441,
#         41.43004118, 50.21280958],
#        [52.20838092, 19.40945393, 68.94891563, ..., 24.35062607,
#          9.00079404, 44.20830172],
#        [88.99601216, 46.75402623, 84.97130446, ..., 30.36984691,
#         44.33200065, 17.22648144]])

# %%
Y = 3.5 * X + np.random.randn(*X.shape) * 20

# %%
Y
# Out:
# array([[122.29671854, 336.74965124, 275.34607654, ..., 217.09183275,
#         171.72458773, 101.59417275],
#        [226.99066833,  23.07527937,  86.64976382, ...,  31.19162094,
#         220.12843071, 147.98815726],
#        [ 23.35238628, 162.00086329,  16.05449652, ...,  56.4175386 ,
#          -7.68513781, 113.03525638],
#        ...,
#        [ 56.5729501 , 237.59114857, 366.15942815, ..., 320.7446224 ,
#         163.42985996, 189.15091591],
#        [191.00904579,  39.52882329, 219.69588612, ..., 122.90167237,
#          27.66935742, 160.38084199],
#        [329.31201199, 196.41594552, 307.41999877, ..., 127.57073211,
#         197.79728145,  92.63057925]])

# %%
import pandas as pd
import numpy as np

# Ensure Y has the same number of samples as X
# If X has changed its number of samples, Y needs to be re-generated accordingly.
# Assuming Y is intended to be generated from a single feature of X, plus noise
if X.shape[0] != Y.shape[0]:
    # Use the first feature of X for generating Y, maintaining the original relationship structure
    Y = 3.5 * X[:, 0].reshape(-1, 1) + np.random.randn(X.shape[0], 1) * 20

# Now, create the DataFrame for plotting. We'll plot the first feature of X against Y.
data = {'X': X[:, 0], 'Y': Y[:,0]}
df = pd.DataFrame(data)
df.plot(x ='X', y='Y', kind = 'scatter')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
print("Slope (Coefficient):", model.coef_[0][0])
print("Intercept:", model.intercept_[0])
# Out:
# Slope (Coefficient): 3.510328000242546
# Intercept: -0.6788447181180004

# %%
model = LinearRegression()
model.fit(X[:, 0].reshape(-1, 1), Y)
# Out:
# LinearRegression()
